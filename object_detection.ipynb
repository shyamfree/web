# %% [markdown]
# <a href="https://colab.research.google.com/github/shyamfree/web/blob/master/object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install package
# !pip install cvlib
# Out:
# ...
#      |████████████████████████████████| 10.0MB 3.5MB/s
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.3-cp36-none-any.whl size=10043491 sha256=146bd24bf44977936cd62a150169aa9a621320becf48030c20dee55669c4ef14
#   Stored in directory: /root/.cache/pip/wheels/c9/83/ca/701a48deacbc78758f33173252feb97297316c40af783264e2
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-cp36-none-any.whl size=12073 sha256=4734303ea8f6e94187f895059e182ae2db9f5eb9b3b26f5054103e7d3081f03f
#   Stored in directory: /root/.cache/pip/wheels/c0/e9/6b/ea01090205e285175842339aa3b491adeb4015206cda272ff0
# Successfully built cvlib progressbar
# ...

# %%
# import necessary packages
import cvlib as cv 
from cvlib.object_detection import draw_bbox
import cv2
from google.colab.patches import cv2_imshow

# %%
# download input image
# !wget https://raw.githubusercontent.com/arunponnusamy/cvlib/master/examples/images/object_detection_input.jpg -O object.jpg
# Out:
# --2020-01-19 09:30:39--  https://raw.githubusercontent.com/arunponnusamy/cvlib/master/examples/images/object_detection_input.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113880 (111K) [image/jpeg]
# Saving to: ‘object.jpg’
#
# object.jpg          100%[===================>] 111.21K  --.-KB/s    in 0.02s
#
# 2020-01-19 09:30:39 (5.11 MB/s) - ‘object.jpg’ saved [113880/113880]

# %%
# load image
image = cv2.imread('object.jpg')

# %%
# run object detector on the image
(bbox, label, conf) = cv.detect_common_objects(image)
print(bbox, label, conf)
# Out:
# [[190, 94, 276, 378], [394, 137, 608, 343], [59, 262, 205, 350]] ['person', 'horse', 'dog'] [0.9999475479125977, 0.9977301955223083, 0.9942072629928589]

# %%
# draw predictions
out = draw_bbox(image, bbox, label, conf)

# %%
cv2_imshow(out)
# Out:
# <PIL.Image.Image image mode=RGB size=640x424 at 0x7FD763728F98>

# %%
# write image to disk
cv2.imwrite('output.jpg', out)
# Out:
# True
